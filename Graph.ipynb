# %%
import networkx as nx
import matplotlib.pyplot as plt
G_fb = nx.read_edgelist("/Users/ali/Desktop/WSP/a/musae_facebook_edges copy.txt" , create_using = nx.Graph(), nodetype=int)
print(nx.info(G_fb))
pos = nx.spring_layout(G_fb)
betcent= nx.betweenness_centrality(G_fb , normalized= True , endpoints=True)
node_color= [20000.0 * G_fb.degree(v) for v in G_fb]
node_size = [v*10000 for v in betcent.values()]
plt.figure(figsize=(20 , 20))
nx.draw_networkx(G_fb, pos= pos, with_labels=False , node_color= node_color , node_size=node_size)
#plt.axis("off")

print(sorted(betcent, key=betcent.get, reverse=True)[:5])
# Out:
# Graph with 22470 nodes and 171002 edges
# [701, 11003, 21729, 19743, 21120]

# %%
import networkx as nx
import matplotlib.pyplot as plt
G_fb = nx.read_edgelist("/Users/ali/Desktop/WSP/a/musae_facebook_edges copy.txt" , create_using = nx.Graph(), nodetype=int)
print(nx.info(G_fb))
pos = nx.spring_layout(G_fb)
betcent= nx.degree_centrality(G_fb)
node_color= [20000.0 * G_fb.degree(v) for v in G_fb]
node_size = [v*10000 for v in betcent.values()]
plt.figure(figsize=(20 , 20))
nx.draw_networkx(G_fb, pos= pos, with_labels=False , node_color= node_color , node_size=node_size)
plt.axis("off")
print(sorted(betcent, key=betcent.get, reverse=True)[:5])
# Out:
# Graph with 22470 nodes and 171002 edges
# [16895, 19743, 21729, 14497, 1387]

# %%
import networkx as nx
import matplotlib.pyplot as plt
G_fb = nx.read_edgelist("/Users/ali/Desktop/WSP/a/musae_facebook_edges copy.txt" , create_using = nx.Graph(), nodetype=int)
print(nx.info(G_fb))
pos = nx.spring_layout(G_fb)
betcent= nx.eigenvector_centrality(G_fb)
node_color= [20000.0 * G_fb.degree(v) for v in G_fb]
node_size = [v*10000 for v in betcent.values()]
plt.figure(figsize=(20 , 20))
nx.draw_networkx(G_fb, pos= pos, with_labels=False , node_color= node_color , node_size=node_size)
plt.axis("off")
print(sorted(betcent, key=betcent.get, reverse=True)[:5])
# Out:
# Graph with 22470 nodes and 171002 edges
# [16895, 14497, 1387, 2442, 8139]

# %%
import networkx as nx
import matplotlib.pyplot as plt
G_fb = nx.read_edgelist("/Users/ali/Desktop/WSP/a/musae_facebook_edges copy.txt" , create_using = nx.Graph(), nodetype=int)
print(nx.info(G_fb))
pos = nx.spring_layout(G_fb)

plt.figure(figsize=(20 , 20))
nx.draw_networkx(G_fb, with_labels=False )
plt.axis("off")

# %%
import networkx as nx
import statistics
import matplotlib.pyplot as plt
G_fb = nx.read_edgelist("/Users/ali/Desktop/WSP/a/musae_facebook_edges copy.txt" , create_using = nx.Graph(), nodetype=int)
list = []
for i in range (0 , len(G_fb)):
    list.append(G_fb.degree[i])
    i+=1
x = statistics.mean(list)
print(min(list))
plt.boxplot(list, notch=None, vert=None, patch_artist=None, widths=None)
plt.figure(figsize=(40 , 40))

plt.show()
# Out:
# 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_frame = pd.DataFrame(a.items(), columns=['Node', 'degree'])
data_frame
plt.boxplot(data_frame['degree'] , notch=None, vert=None, patch_artist=None, widths=None)
plt.show()
